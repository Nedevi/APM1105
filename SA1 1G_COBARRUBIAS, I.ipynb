# %%
import requests
import random

def download_words(url, filename):
    response = requests.get(url)
    if response.status_code == 200:
        with open(filename, 'wb') as f:
            f.write(response.content)
        print('Dataset saved to file.')
    else:
        print('Failed to download dataset.')

def read_words(filename):
    with open(filename, 'r') as f:
        words = f.readlines()
    return [word.strip() for word in words]

def select_word(words):
    return random.choice(words)

def display_word(word, guessed_letters):
    display = ''
    for letter in word:
        if letter in guessed_letters:
            display += letter
        else:
            display += '_ '
    return display

def get_guess(guessed_letters):
    while True:
        guess = input('Enter a letter: ').lower()
        if len(guess) != 1 or not guess.isalpha():
            print('Please enter a single letter.')
        elif guess in guessed_letters:
            print('You already guessed that letter.')
        else:
            return guess

def main():
    url = 'https://raw.githubusercontent.com/AllenDowney/ThinkPython2/master/code/words.txt'
    filename = 'words.txt'
    download_words(url, filename)
    words = read_words(filename)
    word_to_guess = select_word(words)
    guessed_letters = []
    max_guesses = 10
    guesses_left = max_guesses

    
    while True:
        display = display_word(word_to_guess, guessed_letters)
        print('Word:', display)
        print('Guesses left:', guesses_left)

        if '_' not in display:
            print('Congratulations! You guessed the word:', word_to_guess)
            break
        elif guesses_left == 0:
            print('Sorry, you have run out of guesses. The word was:', word_to_guess)
            break

        guess = get_guess(guessed_letters)
        guessed_letters.append(guess)

        if guess in word_to_guess:
            print('Correct guess!')
        else:
            print('Incorrect guess!')
            guesses_left -= 1
            print('Guesses left:', guesses_left)


main()
# Out:
# Dataset saved to file.
# Word: _ _ _ _ _ _ _ _ _ _
# Guesses left: 10
# Enter a letter: a
# Correct guess!
# Word: _ _ _ _ _ _ a_ _ _
# Guesses left: 10
# Enter a letter: d
# Incorrect guess!
# Guesses left: 9
# Word: _ _ _ _ _ _ a_ _ _
# Guesses left: 9
# Enter a letter: f
# Incorrect guess!
# Guesses left: 8
# Word: _ _ _ _ _ _ a_ _ _
# Guesses left: 8
# Enter a letter: e
# Correct guess!
# Word: _ _ e_ _ _ a_ _ _
# Guesses left: 8
# Enter a letter: q
# Incorrect guess!
# Guesses left: 7
# Word: _ _ e_ _ _ a_ _ _
# Guesses left: 7
# Enter a letter: z
# Incorrect guess!
# Guesses left: 6
# Word: _ _ e_ _ _ a_ _ _
# Guesses left: 6
# Enter a letter: c
# Correct guess!
# Word: c_ e_ _ ca_ _ _
# Guesses left: 6
# Enter a letter: f
# You already guessed that letter.
# Enter a letter: g
# Incorrect guess!
# Guesses left: 5
# Word: c_ e_ _ ca_ _ _
# Guesses left: 5
# Enter a letter: t
# Incorrect guess!
# Guesses left: 4
# Word: c_ e_ _ ca_ _ _
# Guesses left: 4
# Enter a letter: e
# You already guessed that letter.
# Enter a letter: y
# Correct guess!
# Word: c_ e_ _ ca_ _ y
# Guesses left: 4
# Enter a letter: h
# Correct guess!
# Word: che_ _ ca_ _ y
# Guesses left: 4
# Enter a letter: b
# Incorrect guess!
# Guesses left: 3
# Word: che_ _ ca_ _ y
# Guesses left: 3
# Enter a letter: g
# You already guessed that letter.
# Enter a letter: n
# Incorrect guess!
# Guesses left: 2
# Word: che_ _ ca_ _ y
# Guesses left: 2
# Enter a letter: w
# Incorrect guess!
# Guesses left: 1
# Word: che_ _ ca_ _ y
# Guesses left: 1
# Enter a letter: a
# You already guessed that letter.
# Enter a letter: r
# Incorrect guess!
# Guesses left: 0
# Word: che_ _ ca_ _ y
# Guesses left: 0
# Sorry, you have run out of guesses. The word was: chemically
